# %%
import random
L1 = random.randint(1,10e9)
L2 = random.randint(1,10e9)
L3 = random.randint(1,100)
L4 = random.randint(1,100)
L5 = random.randint(1,100)
L6 = random.randint(1,100)
L7 = random.randint(1,100)
L8 = random.randint(1,100)
L9 = random.randint(1,100)
L10 = random.randint(1,100)
L11 = random.randint(1,100)
L12 = random.randint(1,100)
L13 = random.randint(1,100)
L14 = random.randint(1,100)
L15 = random.randint(1,100)
L16 = random.randint(1,100)
L17 = random.randint(1,100)
L18 = random.randint(1,100)
L19 = random.randint(1,100)
L20 = random.randint(1,100)
L21 = random.randint(1,100)
L22 = random.randint(1,100)
L23 = random.randint(1,10e9)
L24 = random.randint(1,10e9)
L25 = random.randint(1,10e9)
L26 = random.randint(1,10e9)
L27 = random.randint(1,10e9)
L28 = random.randint(1,10e9)
L29 = random.randint(1,10e9)
L30 = random.randint(1,10e9)
L31 = random.randint(1,10e9)
L32 = random.randint(1,10e9)
L33 = random.randint(1,10e9)
L34 = random.randint(1,10e9)
L35 = random.randint(1,10e9)
L36 = random.randint(1,10e9)
L37 = random.randint(1,10e9)
L38 = random.randint(1,10e9)
L39 = random.randint(1,10e9)
L40 = random.randint(1,10e9)
L41 = random.randint(1,10e9)
L42 = random.randint(1,10e9)
L43 = random.randint(1,10e9)
L44 = random.randint(1,10e9)
L45 = random.randint(1,10e9)
L46 = random.randint(1,10e9)
L47 = random.randint(1,10e9)
L48 = random.randint(1,10e9)
L49 = random.randint(1,10e9)
L50 = random.randint(1,10e9)
L51 = random.randint(1,10e9)
L52 = random.randint(1,10e9)
L53 = random.randint(1,100)
L54 = random.randint(1,100)
L55 = random.randint(1,100)
L56 = random.randint(1,100)
L57 = random.randint(1,100)
L58 = random.randint(1,100)
L59 = random.randint(1,100)
L60 = random.randint(1,100)
L61 = random.randint(1,100)
L62 = random.randint(1,100)
L63 = random.randint(1,100)
L64 = random.randint(1,100)
L65 = random.randint(1,100)
L66 = random.randint(1,100)
L67 = random.randint(1,100)
L68 = random.randint(1,100)
L69 = random.randint(1,100)
L70 = random.randint(1,100)
L71 = random.randint(1,100)
L72 = random.randint(1,100)
L73 = random.randint(1,10e9)
L74 = random.randint(1,10e9)
L75 = random.randint(1,10e9)
L76 = random.randint(1,10e9)
L77 = random.randint(1,10e9)
L78 = random.randint(1,10e9)
L79 = random.randint(1,10e9)
L80 = random.randint(1,10e9)
L81 = random.randint(1,10e9)
L82 = random.randint(1,10e9)
L83 = random.randint(1,10e9)
L84 = random.randint(1,10e9)
L85 = random.randint(1,10e9)
L86 = random.randint(1,10e9)
L87 = random.randint(1,10e9)
L88 = random.randint(1,10e9)
L89 = random.randint(1,10e9)
L90 = random.randint(1,10e9)
L91 = random.randint(1,10e9)
L92 = random.randint(1,10e9)
L93 = random.randint(1,10e9)
L94 = random.randint(1,10e9)
L95 = random.randint(1,10e9)
L96 = random.randint(1,10e9)
L97 = random.randint(1,10e9)
L98 = random.randint(1,10e9)
L99 = random.randint(1,10e9)
L100 = random.randint(1,10e9)
def bubble_sort(M):
  N = len(M)
  for i in range(0,N-1):
    for j in range(i+1, N):
      if M[j] < M[i]:
        M[i], M[j] = M[j], M[i]
M = [L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,L11,L12,L13,L14,L15,L16,L17,L18,L19,L20,L21,L22,L23,L24,L25,L26,L27,L28,L29,L30,L31,L32,L33,L34,L35,L36,L37,L38,L39,L40,L41,L42,L43,L44,L45,L46,L47,L48,L49,L50,L51,L52,L53,L54,L55,L56,L57,L58,L59,L60,L61,L62,L63,L64,L65,L66,L67,L68,L69,L70,L71,L72,L73,L74,L75,L76,L77,L78,L79,L80,L81,L82,L83,L84,L85,L86,L87,L88,L89,L90,L91,L92,L93,L94,L95,L96,L97,L98,L99,L100,]
bubble_sort(M)

print(M)
# Out:
# [1, 1, 2, 6, 9, 11, 20, 29, 33, 37, 42, 43, 48, 56, 56, 58, 58, 66, 69, 70, 70, 73, 73, 74, 76, 76, 76, 76, 79, 81, 82, 82, 84, 85, 92, 92, 93, 94, 96, 100, 40480, 314897773, 396343745, 682801761, 763751176, 918269549, 947613858, 1013092447, 1092129060, 1150961055, 1390064933, 1418032344, 1453488634, 1966035025, 2580614001, 2633197318, 2830267341, 2929317922, 3067133390, 3205907267, 3366555315, 3446367586, 3481189785, 3694206838, 3827611531, 3946967064, 4125767093, 4299611676, 4405738429, 4597765163, 5082925570, 5101741718, 5768730550, 5810252530, 6172886802, 6251829925, 6617094659, 6695426539, 6893626739, 6897138983, 7152131877, 7167284284, 7169425888, 7420768626, 7467781406, 7471252443, 7474952813, 7677262424, 7815804679, 7896124377, 8073017432, 8178109802, 8372234361, 8563839252, 8751481349, 8870514870, 8992781872, 9536956144, 9577544798, 9678151964]

# %%
import random
L1 = random.randint(1,10e9)
L2 = random.randint(1,10e9)
L3 = random.randint(1,100)
L4 = random.randint(1,100)
L5 = random.randint(1,100)
L6 = random.randint(1,100)
L7 = random.randint(1,100)
L8 = random.randint(1,100)
L9 = random.randint(1,100)
L10 = random.randint(1,100)
L11 = random.randint(1,100)
L12 = random.randint(1,100)
L13 = random.randint(1,100)
L14 = random.randint(1,100)
L15 = random.randint(1,100)
L16 = random.randint(1,100)
L17 = random.randint(1,100)
L18 = random.randint(1,100)
L19 = random.randint(1,100)
L20 = random.randint(1,100)
L21 = random.randint(1,100)
L22 = random.randint(1,100)
L23 = random.randint(1,10e9)
L24 = random.randint(1,10e9)
L25 = random.randint(1,10e9)
L26 = random.randint(1,10e9)
L27 = random.randint(1,10e9)
L28 = random.randint(1,10e9)
L29 = random.randint(1,10e9)
L30 = random.randint(1,10e9)
L31 = random.randint(1,10e9)
L32 = random.randint(1,10e9)
L33 = random.randint(1,10e9)
L34 = random.randint(1,10e9)
L35 = random.randint(1,10e9)
L36 = random.randint(1,10e9)
L37 = random.randint(1,10e9)
L38 = random.randint(1,10e9)
L39 = random.randint(1,10e9)
L40 = random.randint(1,10e9)
L41 = random.randint(1,10e9)
L42 = random.randint(1,10e9)
L43 = random.randint(1,10e9)
L44 = random.randint(1,10e9)
L45 = random.randint(1,10e9)
L46 = random.randint(1,10e9)
L47 = random.randint(1,10e9)
L48 = random.randint(1,10e9)
L49 = random.randint(1,10e9)
L50 = random.randint(1,10e9)
L51 = random.randint(1,10e9)
L52 = random.randint(1,10e9)
L53 = random.randint(1,100)
L54 = random.randint(1,100)
L55 = random.randint(1,100)
L56 = random.randint(1,100)
L57 = random.randint(1,100)
L58 = random.randint(1,100)
L59 = random.randint(1,100)
L60 = random.randint(1,100)
L61 = random.randint(1,100)
L62 = random.randint(1,100)
L63 = random.randint(1,100)
L64 = random.randint(1,100)
L65 = random.randint(1,100)
L66 = random.randint(1,100)
L67 = random.randint(1,100)
L68 = random.randint(1,100)
L69 = random.randint(1,100)
L70 = random.randint(1,100)
L71 = random.randint(1,100)
L72 = random.randint(1,100)
L73 = random.randint(1,10e9)
L74 = random.randint(1,10e9)
L75 = random.randint(1,10e9)
L76 = random.randint(1,10e9)
L77 = random.randint(1,10e9)
L78 = random.randint(1,10e9)
L79 = random.randint(1,10e9)
L80 = random.randint(1,10e9)
L81 = random.randint(1,10e9)
L82 = random.randint(1,10e9)
L83 = random.randint(1,10e9)
L84 = random.randint(1,10e9)
L85 = random.randint(1,10e9)
L86 = random.randint(1,10e9)
L87 = random.randint(1,10e9)
L88 = random.randint(1,10e9)
L89 = random.randint(1,10e9)
L90 = random.randint(1,10e9)
L91 = random.randint(1,10e9)
L92 = random.randint(1,10e9)
L93 = random.randint(1,10e9)
L94 = random.randint(1,10e9)
L95 = random.randint(1,10e9)
L96 = random.randint(1,10e9)
L97 = random.randint(1,10e9)
L98 = random.randint(1,10e9)
L99 = random.randint(1,10e9)
L100 = random.randint(1,10e9)
def selection_sort(L):
  n = len(L)
  for i in range(n):
    min_index = i
    for j in range(i+1,n):
      if L[j] < L[min_index]:
        min_index = j
    L[i], L[min_index] = L[min_index], L[i]

L = [L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,L11,L12,L13,L14,L15,L16,L17,L18,L19,L20,L21,L22,L23,L24,L25,L26,L27,L28,L29,L30,L31,L32,L33,L34,L35,L36,L37,L38,L39,L40,L41,L42,L43,L44,L45,L46,L47,L48,L49,L50,L51,L52,L53,L54,L55,L56,L57,L58,L59,L60,L61,L62,L63,L64,L65,L66,L67,L68,L69,L70,L71,L72,L73,L74,L75,L76,L77,L78,L79,L80,L81,L82,L83,L84,L85,L86,L87,L88,L89,L90,L91,L92,L93,L94,L95,L96,L97,L98,L99,L100,]
selection_sort(L)

print(L)
# Out:
# [4, 5, 7, 7, 8, 11, 13, 15, 17, 18, 21, 21, 23, 33, 33, 37, 39, 40, 43, 44, 44, 46, 49, 59, 59, 62, 69, 70, 70, 78, 79, 80, 81, 84, 87, 92, 94, 95, 98, 98, 58674724, 180262634, 405439404, 506402381, 754603546, 804107688, 1155954701, 1216773291, 1585355432, 1717910469, 1744268668, 2000865058, 2007370934, 2262713007, 2273393987, 2341043156, 2488025196, 2865318187, 3012455211, 3021390865, 3054195020, 3531107041, 3784033412, 3836196273, 4104515907, 4126856521, 4257954272, 4262197823, 4832111972, 5086645548, 5124252130, 5439987053, 5557010710, 5770887026, 5784426168, 5799547545, 6004073192, 6367377323, 6371735939, 6471260840, 6741432392, 7199544398, 7232078501, 7237607350, 7273862971, 7385479749, 7426905014, 7831471602, 7874070830, 7974685678, 8062503852, 8380957417, 8398959254, 8693760951, 9140624195, 9350110479, 9365444342, 9405051552, 9727099943, 9986631135]

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x) :
  return (0.00661/np.log(100))*(x)*(np.log(x))

x = np.linspace(100,3000,100)
y = f(x)
plt.plot(x,y)
plt.show()

# %%
import numpy as np

x = np.log(np.e)
print(x)
# Out:
# 1.0

# %%
import random
L1 = random.randint(1,10e9)
L2 = random.randint(1,10e9)
L3 = random.randint(1,100)
L4 = random.randint(1,100)
L5 = random.randint(1,100)
L6 = random.randint(1,100)
L7 = random.randint(1,100)
L8 = random.randint(1,100)
L9 = random.randint(1,100)
L10 = random.randint(1,100)
L11 = random.randint(1,100)
L12 = random.randint(1,100)
L13 = random.randint(1,100)
L14 = random.randint(1,100)
L15 = random.randint(1,100)
L16 = random.randint(1,100)
L17 = random.randint(1,100)
L18 = random.randint(1,100)
L19 = random.randint(1,100)
L20 = random.randint(1,100)
L21 = random.randint(1,100)
L22 = random.randint(1,100)
L23 = random.randint(1,10e9)
L24 = random.randint(1,10e9)
L25 = random.randint(1,10e9)
L26 = random.randint(1,10e9)
L27 = random.randint(1,10e9)
L28 = random.randint(1,10e9)
L29 = random.randint(1,10e9)
L30 = random.randint(1,10e9)
L31 = random.randint(1,10e9)
L32 = random.randint(1,10e9)
L33 = random.randint(1,10e9)
L34 = random.randint(1,10e9)
L35 = random.randint(1,10e9)
L36 = random.randint(1,10e9)
L37 = random.randint(1,10e9)
L38 = random.randint(1,10e9)
L39 = random.randint(1,10e9)
L40 = random.randint(1,10e9)
L41 = random.randint(1,10e9)
L42 = random.randint(1,10e9)
L43 = random.randint(1,10e9)
L44 = random.randint(1,10e9)
L45 = random.randint(1,10e9)
L46 = random.randint(1,10e9)
L47 = random.randint(1,10e9)
L48 = random.randint(1,10e9)
L49 = random.randint(1,10e9)
L50 = random.randint(1,10e9)
L51 = random.randint(1,10e9)
L52 = random.randint(1,10e9)
L53 = random.randint(1,100)
L54 = random.randint(1,100)
L55 = random.randint(1,100)
L56 = random.randint(1,100)
L57 = random.randint(1,100)
L58 = random.randint(1,100)
L59 = random.randint(1,100)
L60 = random.randint(1,100)
L61 = random.randint(1,100)
L62 = random.randint(1,100)
L63 = random.randint(1,100)
L64 = random.randint(1,100)
L65 = random.randint(1,100)
L66 = random.randint(1,100)
L67 = random.randint(1,100)
L68 = random.randint(1,100)
L69 = random.randint(1,100)
L70 = random.randint(1,100)
L71 = random.randint(1,100)
L72 = random.randint(1,100)
L73 = random.randint(1,10e9)
L74 = random.randint(1,10e9)
L75 = random.randint(1,10e9)
L76 = random.randint(1,10e9)
L77 = random.randint(1,10e9)
L78 = random.randint(1,10e9)
L79 = random.randint(1,10e9)
L80 = random.randint(1,10e9)
L81 = random.randint(1,10e9)
L82 = random.randint(1,10e9)
L83 = random.randint(1,10e9)
L84 = random.randint(1,10e9)
L85 = random.randint(1,10e9)
L86 = random.randint(1,10e9)
L87 = random.randint(1,10e9)
L88 = random.randint(1,10e9)
L89 = random.randint(1,10e9)
L90 = random.randint(1,10e9)
L91 = random.randint(1,10e9)
L92 = random.randint(1,10e9)
L93 = random.randint(1,10e9)
L94 = random.randint(1,10e9)
L95 = random.randint(1,10e9)
L96 = random.randint(1,10e9)
L97 = random.randint(1,10e9)
L98 = random.randint(1,10e9)
L99 = random.randint(1,10e9)
L100 = random.randint(1,10e9)

def merge_sort(array, left_index, right_index):
    if left_index >= right_index:
        return

    middle = (left_index + right_index)//2
    merge_sort(array, left_index, middle)
    merge_sort(array, middle + 1, right_index)
    merge(array, left_index, right_index, middle)

def merge(array, left_index, right_index, middle):
    # Make copies of both arrays we're trying to merge

    # The second parameter is non-inclusive, so we have to increase by 1
    left_copy = array[left_index:middle + 1]
    right_copy = array[middle+1:right_index+1]

    # Initial values for variables that we use to keep
    # track of where we are in each array
    left_copy_index = 0
    right_copy_index = 0
    sorted_index = left_index

    # Go through both copies until we run out of elements in one
    while left_copy_index < len(left_copy) and right_copy_index < len(right_copy):

        # If our left_copy has the smaller element, put it in the sorted
        # part and then move forward in left_copy (by increasing the pointer)
        if left_copy[left_copy_index] <= right_copy[right_copy_index]:
            array[sorted_index] = left_copy[left_copy_index]
            left_copy_index = left_copy_index + 1
        # Opposite from above
        else:
            array[sorted_index] = right_copy[right_copy_index]
            right_copy_index = right_copy_index + 1

        # Regardless of where we got our element from
        # move forward in the sorted part
        sorted_index = sorted_index + 1

    # We ran out of elements either in left_copy or right_copy
    # so we will go through the remaining elements and add them
    while left_copy_index < len(left_copy):
        array[sorted_index] = left_copy[left_copy_index]
        left_copy_index = left_copy_index + 1
        sorted_index = sorted_index + 1

    while right_copy_index < len(right_copy):
        array[sorted_index] = right_copy[right_copy_index]
        right_copy_index = right_copy_index + 1
        sorted_index = sorted_index + 1

array = [L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,L11,L12,L13,L14,L15,L16,L17,L18,L19,L20,L21,L22,L23,L24,L25,L26,L27,L28,L29,L30,L31,L32,L33,L34,L35,L36,L37,L38,L39,L40,L41,L42,L43,L44,L45,L46,L47,L48,L49,L50,L51,L52,L53,L54,L55,L56,L57,L58,L59,L60,L61,L62,L63,L64,L65,L66,L67,L68,L69,L70,L71,L72,L73,L74,L75,L76,L77,L78,L79,L80,L81,L82,L83,L84,L85,L86,L87,L88,L89,L90,L91,L92,L93,L94,L95,L96,L97,L98,L99,L100]
merge_sort(array, 0, len(array) -1)
print(array)
# Out:
# [2, 2, 8, 9, 10, 16, 16, 22, 24, 29, 30, 31, 32, 33, 36, 39, 45, 45, 53, 55, 56, 59, 60, 66, 68, 69, 70, 70, 71, 76, 76, 78, 81, 92, 92, 95, 96, 97, 98, 100, 68902243, 220496788, 316571631, 324277301, 409657145, 529899513, 629780352, 665874316, 1050642389, 1097662914, 1162716615, 1262261539, 1527771804, 1702679695, 1917940905, 2202270299, 2285777136, 2453226649, 2665754689, 3037587236, 3421063875, 3436964384, 3448349169, 3960290242, 4201181443, 4340523688, 4431994495, 4457031034, 4623401238, 5008640114, 5084540248, 5495683480, 5559398744, 5589817286, 5786705149, 5881357625, 5919273753, 5994147011, 6050557811, 6095891190, 6117482180, 6251079553, 6297450309, 6453481146, 7536133095, 7558041757, 7702659301, 8092769593, 8156028824, 8279244518, 8298273627, 8461085049, 8704387458, 8750101481, 8773995481, 8889001138, 9295507605, 9401206955, 9488091140, 9564506031]

# %%
import random
L1 = random.randint(1,10e9)
L2 = random.randint(1,10e9)
L3 = random.randint(1,100)
L4 = random.randint(1,100)
L5 = random.randint(1,100)
L6 = random.randint(1,100)
L7 = random.randint(1,100)
L8 = random.randint(1,100)
L9 = random.randint(1,100)
L10 = random.randint(1,100)
L11 = random.randint(1,100)
L12 = random.randint(1,100)
L13 = random.randint(1,100)
L14 = random.randint(1,100)
L15 = random.randint(1,100)
L16 = random.randint(1,100)
L17 = random.randint(1,100)
L18 = random.randint(1,100)
L19 = random.randint(1,100)
L20 = random.randint(1,100)
L21 = random.randint(1,100)
L22 = random.randint(1,100)
L23 = random.randint(1,10e9)
L24 = random.randint(1,10e9)
L25 = random.randint(1,10e9)
L26 = random.randint(1,10e9)
L27 = random.randint(1,10e9)
L28 = random.randint(1,10e9)
L29 = random.randint(1,10e9)
L30 = random.randint(1,10e9)
L31 = random.randint(1,10e9)
L32 = random.randint(1,10e9)
L33 = random.randint(1,10e9)
L34 = random.randint(1,10e9)
L35 = random.randint(1,10e9)
L36 = random.randint(1,10e9)
L37 = random.randint(1,10e9)
L38 = random.randint(1,10e9)
L39 = random.randint(1,10e9)
L40 = random.randint(1,10e9)
L41 = random.randint(1,10e9)
L42 = random.randint(1,10e9)
L43 = random.randint(1,10e9)
L44 = random.randint(1,10e9)
L45 = random.randint(1,10e9)
L46 = random.randint(1,10e9)
L47 = random.randint(1,10e9)
L48 = random.randint(1,10e9)
L49 = random.randint(1,10e9)
L50 = random.randint(1,10e9)
L51 = random.randint(1,10e9)
L52 = random.randint(1,10e9)
L53 = random.randint(1,100)
L54 = random.randint(1,100)
L55 = random.randint(1,100)
L56 = random.randint(1,100)
L57 = random.randint(1,100)
L58 = random.randint(1,100)
L59 = random.randint(1,100)
L60 = random.randint(1,100)
L61 = random.randint(1,100)
L62 = random.randint(1,100)
L63 = random.randint(1,100)
L64 = random.randint(1,100)
L65 = random.randint(1,100)
L66 = random.randint(1,100)
L67 = random.randint(1,100)
L68 = random.randint(1,100)
L69 = random.randint(1,100)
L70 = random.randint(1,100)
L71 = random.randint(1,100)
L72 = random.randint(1,100)
L73 = random.randint(1,10e9)
L74 = random.randint(1,10e9)
L75 = random.randint(1,10e9)
L76 = random.randint(1,10e9)
L77 = random.randint(1,10e9)
L78 = random.randint(1,10e9)
L79 = random.randint(1,10e9)
L80 = random.randint(1,10e9)
L81 = random.randint(1,10e9)
L82 = random.randint(1,10e9)
L83 = random.randint(1,10e9)
L84 = random.randint(1,10e9)
L85 = random.randint(1,10e9)
L86 = random.randint(1,10e9)
L87 = random.randint(1,10e9)
L88 = random.randint(1,10e9)
L89 = random.randint(1,10e9)
L90 = random.randint(1,10e9)
L91 = random.randint(1,10e9)
L92 = random.randint(1,10e9)
L93 = random.randint(1,10e9)
L94 = random.randint(1,10e9)
L95 = random.randint(1,10e9)
L96 = random.randint(1,10e9)
L97 = random.randint(1,10e9)
L98 = random.randint(1,10e9)
L99 = random.randint(1,10e9)
L100 = random.randint(1,10e9)
def insertionSort(L):
 
    # Traverse through 1 to len(arr)
    for i in range(1, len(L)):
 
        key = L[i]
 
        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        j = i-1
        while j >= 0 and key < L[j] :
                L[j + 1] = L[j]
                j -= 1
        L[j + 1] = key
 
 
# Driver code to test above
L = [L1,L2,L3,L4,L5,L6,L7,L8,L9,L10,L11,L12,L13,L14,L15,L16,L17,L18,L19,L20,L21,L22,L23,L24,L25,L26,L27,L28,L29,L30,L31,L32,L33,L34,L35,L36,L37,L38,L39,L40,L41,L42,L43,L44,L45,L46,L47,L48,L49,L50,L51,L52,L53,L54,L55,L56,L57,L58,L59,L60,L61,L62,L63,L64,L65,L66,L67,L68,L69,L70,L71,L72,L73,L74,L75,L76,L77,L78,L79,L80,L81,L82,L83,L84,L85,L86,L87,L88,L89,L90,L91,L92,L93,L94,L95,L96,L97,L98,L99,L100]
insertionSort(L)
print(L)
# Out:
# [2, 8, 9, 11, 11, 13, 15, 16, 16, 17, 18, 20, 20, 20, 27, 29, 32, 32, 34, 35, 42, 46, 46, 47, 50, 51, 53, 54, 59, 63, 66, 72, 72, 73, 73, 75, 77, 88, 89, 94, 211045264, 256406597, 351958436, 352405451, 444574126, 717955129, 1136588493, 1177578046, 1189507438, 1395860958, 1424213280, 1519239880, 1585067941, 1735803245, 1948625999, 2103783488, 2189324859, 2242209920, 2247716655, 2320814464, 2567621306, 2653831820, 2792650216, 2965234541, 3326571081, 3416574129, 3605709807, 3800065995, 4048041157, 4329588154, 4681147468, 4957387321, 5138544073, 5205150772, 5212617562, 5404927859, 5480911179, 5637638958, 5926707674, 6506094903, 6511348474, 6809435293, 7423251256, 7456882091, 7544436532, 7577705917, 7831587973, 7906075912, 8008207571, 8020637072, 8617386384, 8762593158, 8859775667, 9148402951, 9187583548, 9292944143, 9325179004, 9755217120, 9867507749, 9937668431]
