# %%
#RUNGE KUTTA ORDE TINGGI

from math import e
def f1(t,u1,u2,u3):
  return u1 + 2*u2 - 2*u3 + e**(-t)
def f2(t,u1,u2,u3):
  return u2 + u3 - 2*e**(-t)
def f3(t,u1,u2,u3):
  return u1 + 2*u2 + e**(-t)
h = 0.1
w1_0 = 3
w2_0 = -1
w3_0 = 1

i = 0

while i <= 9:
  t_i = i*h
  k1_1 = h*f1(t_i,w1_0,w2_0,w3_0)
  k1_2 = h*f2(t_i,w1_0,w2_0,w3_0)
  k1_3 = h*f3(t_i,w1_0,w2_0,w3_0)
  k2_1 = h*f1(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k2_2 = h*f2(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k2_3 = h*f3(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k3_1 = h*f1(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k3_2 = h*f2(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k3_3 = h*f3(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k4_1 = h*f1(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  k4_2 = h*f2(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  k4_3 = h*f3(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  w1 = w1_0 + (1/6)*(k1_1 + 2*k2_1 + 2*k3_1 + k4_1)
  w2 = w2_0 + (1/6)*(k1_2 + 2*k2_2 + 2*k3_2 + k4_2)
  w3 = w3_0 + (1/6)*(k1_3 + 2*k2_3 + 2*k3_3 + k4_3)
  print('untuk i =',i)
  print('w1 :', w1)
  print('w2 :', w2)
  print('w3 : ', w3)
  i = i + 1
  w1_0 = w1
  w2_0 = w2
  w3_0 = w3
# Out:
# untuk i = 0
# w1 : 2.95601282574026
# w2 : -1.1908630117577965
# w3 :  1.1743120738580144
# untuk i = 1
# w1 : 2.8282000118596344
# w2 : -1.3671709978292994
# w3 :  1.2943053482113367
# untuk i = 2
# w1 : 2.6230050150948507
# w2 : -1.5351673664108187
# w3 :  1.355081204132421
# untuk i = 3
# w1 : 2.3471528205747165
# w2 : -1.702133138706904
# w3 :  1.3509684302538516
# untuk i = 4
# w1 : 2.007629534537891
# w2 : -1.8766033591159454
# w3 :  1.2753297166078112
# untuk i = 5
# w1 : 1.6116549157012177
# w2 : -2.0686275901674476
# w3 :  1.1203174766066093
# untuk i = 6
# w1 : 1.1666485434298504
# w2 : -2.2900851286092108
# w3 :  0.8765685508114908
# untuk i = 7
# w1 : 0.6801903441194296
# w2 : -2.555067896377948
# w3 :  0.5328250591190158
# untuk i = 8
# w1 : 0.15997621708846566
# w2 : -2.8803467885843723
# w3 :  0.07546587090983609
# untuk i = 9
# w1 : -0.3862304827680181
# w2 : -3.285940713040603
# w3 :  -0.5120702580005883

# %%
from math import e, sin, cos
def u1(t):
  return -3*e**(-t) - 3*sin(t) + 6*cos(t)
def u2(t):
  return (3/2)*e**(-t) + (3/10)*sin(t) - (21/10)*cos(t) - (2/5)*e**(2*t)
def u3(t):
  return -e**(-t) + (12/5)*cos(t) + (9/5)*sin(t)-(2/5)*e**(2*t)

h = 0.1
i = 0

while i <= 10 :
  t_i = i*h
  print('untuk i =',i)
  print('u1 = ', u1(t_i))
  print('u2 = ', u2(t_i))
  print('u3 = ', u3(t_i))
  i = i + 1
# Out:
# untuk i = 0
# u1 =  3.0
# u2 =  -1.0
# u3 =  0.9999999999999999
# untuk i = 1
# u1 =  2.956012487619792
# u2 =  -1.1908636982999343
# u3 =  1.174311625331525
# untuk i = 2
# u1 =  2.828199215428321
# u2 =  -1.3671727636676247
# u3 =  1.2943039501155997
# untuk i = 3
# u1 =  2.6230036527244636
# u2 =  -1.5351707542989976
# u3 =  1.355078205053944
# untuk i = 4
# u1 =  2.3471507989844413
# u2 =  -1.702138887056992
# u3 =  1.3509629843298687
# untuk i = 5
# u1 =  2.007626776391727
# u2 =  -1.87661246020319
# u3 =  1.2753207269282083
# untuk i = 6
# u1 =  1.6116513609908836
# u2 =  -2.0686413642453934
# u3 =  1.1203035227056461
# untuk i = 7
# u1 =  1.1666441506196286
# u2 =  -2.290105318176874
# u3 =  0.8765477959813368
# untuk i = 8
# u1 =  0.6801850910327594
# u2 =  -2.555096785941404
# u3 =  0.5327951321770703
# untuk i = 9
# u1 =  0.15997010151973878
# u2 =  -2.8803873566344302
# u3 =  0.0754237156732871
# untuk i = 10
# u1 =  -0.3862374427291777
# u2 =  -3.285996824695821
# ...

# %%
#RUNGE KUTTA ORDE TINGGI

from math import e
def f1(t,u1,u2,u3):
  return u2
def f2(t,u1,u2,u3):
  return u3
def f3(t,u1,u2,u3):
  return -u3 + 4*u2 + 4*u1
h = 0.2
w1_0 = 3
w2_0 = -1
w3_0 = 9

i = 0

while i <= 9:
  t_i = i*h
  k1_1 = h*f1(t_i,w1_0,w2_0,w3_0)
  k1_2 = h*f2(t_i,w1_0,w2_0,w3_0)
  k1_3 = h*f3(t_i,w1_0,w2_0,w3_0)
  k2_1 = h*f1(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k2_2 = h*f2(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k2_3 = h*f3(t_i + h/2, w1_0 + (1/2)*k1_1, w2_0 + (1/2)*k1_2 , w3_0 + (1/2)*k1_3)
  k3_1 = h*f1(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k3_2 = h*f2(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k3_3 = h*f3(t_i + h/2, w1_0 + (1/2)*k2_1, w2_0 + (1/2)*k2_2 , w3_0 + (1/2)*k2_3)
  k4_1 = h*f1(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  k4_2 = h*f2(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  k4_3 = h*f3(t_i + h, w1_0 + k3_1, w2_0 + k3_2, w3_0 + k3_3)
  w1 = w1_0 + (1/6)*(k1_1 + 2*k2_1 + 2*k3_1 + k4_1)
  w2 = w2_0 + (1/6)*(k1_2 + 2*k2_2 + 2*k3_2 + k4_2)
  w3 = w3_0 + (1/6)*(k1_3 + 2*k2_3 + 2*k3_3 + k4_3)
  print('untuk i =',i)
  print('w1 :', w1)
  print('w2 :', w2)
  print('w3 : ', w3)
  i = i + 1
  w1_0 = w1
  w2_0 = w2
  w3_0 = w3
# Out:
# untuk i = 0
# w1 : 2.9808666666666666
# w2 : 0.8239333333333332
# w3 :  9.467266666666667
# untuk i = 1
# w1 : 3.3450287688888887
# w2 : 2.8813400844444446
# w3 :  11.369142262222223
# untuk i = 2
# w1 : 4.169625781639407
# w2 : 5.487593081919703
# w3 :  15.032052651854519
# untuk i = 3
# w1 : 5.603146665472462
# w2 : 9.050317997960814
# w3 :  21.06458277656792
# untuk i = 4
# w1 : 7.8900949769136
# w2 : 14.134870180938567
# w3 :  30.456724193278497
# untuk i = 5
# w1 : 11.411109228288307
# w2 : 21.555487149866313
# w3 :  44.74083719126986
# untuk i = 6
# w1 : 16.745061449784977
# w2 : 32.50687227280534
# w3 :  66.24043858684327
# untuk i = 7
# w1 : 24.76321586762994
# w2 : 48.757522445252874
# w3 :  98.44715864557209
# untuk i = 8
# w1 : 36.77072345105039
# w2 : 72.93612389837952
# w3 :  146.58698307385606
# untuk i = 9
# w1 : 54.71839856873957
# w2 : 108.95742850411649
# w3 :  218.46757562966675

# %%
from math import e, sin, cos
def u1(t):
  return e**(-t) + e**(2*t) + e**(-2*t)
def u2(t):
  return -e**(-t) + 2*e**(2*t) - 2*e**(-2*t)
def u3(t):
  return e**(-t) + 4*e**(2*t) + 4*e**(-2*t)

h = 0.2
i = 0

while i <= 10 :
  t_i = i*h
  print('untuk i =',i)
  print('u1 = ', u1(t_i))
  print('u2 = ', u2(t_i))
  print('u3 = ', u3(t_i))
  i = i + 1
# Out:
# untuk i = 0
# u1 =  3.0
# u2 =  -1.0
# u3 =  9.0
# untuk i = 1
# u1 =  2.9808754967548916
# u2 =  0.8242785501332803
# u3 =  9.46730972778562
# untuk i = 2
# u1 =  3.3451899386453285
# u2 =  2.882103882714852
# u3 =  11.369799616474396
# untuk i = 3
# u1 =  4.170122770742776
# u2 =  5.489033785554665
# u3 =  15.034056174689026
# untuk i = 4
# u1 =  5.604257906506992
# u2 =  9.052942848683697
# u3 =  21.069044733676304
# untuk i = 5
# u1 =  7.892270823338704
# u2 =  14.139562190216632
# u3 =  30.46544496984049
# untuk i = 6
# u1 =  11.41508854584322
# u2 =  21.563722642792182
# u3 =  44.756771547636276
# untuk i = 7
# u1 =  16.752053797663876
# u2 =  32.52107645300206
# u3 =  66.2684242988307
# untuk i = 8
# u1 =  24.77518891908237
# u2 =  48.78163946826731
# u3 =  98.49506612234552
# untuk i = 9
# u1 =  36.79085705434686
# u2 =  72.97652255423979
# u3 =  146.6675315527227
# untuk i = 10
# u1 =  54.75180095526958
# u2 =  109.02433350527437
# u3 =  218.60119797136846

# %%
def y(t):
  return e**(-10*t+1) + t

h = 0.1
i = 0

while i <= 9:
  t_i = h*i
  w = t_i + 0.1
  print('w', w)
  print('y' , y(t_i+h))
  error = (abs(y(t_i + h)-w))
  print('error', error)
  i = i + 1
# Out:
# w 0.1
# y 1.1
# error 1.0
# w 0.2
# y 0.5678794411714423
# error 0.3678794411714423
# w 0.30000000000000004
# y 0.4353352832366127
# error 0.13533528323661265
# w 0.4
# y 0.449787068367864
# error 0.04978706836786395
# w 0.5
# y 0.5183156388887342
# error 0.01831563888873422
# w 0.6
# y 0.6067379469990855
# error 0.006737946999085476
# w 0.7000000000000001
# y 0.7024787521766664
# error 0.0024787521766663767
# w 0.8
# y 0.8009118819655545
# error 0.000911881965554473
# w 0.9
# y 0.9003354626279025
# error 0.00033546262790251635
# w 1.0
# y 1.0001234098040868
# error 0.0001234098040867604
