# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-6b34133e-df0b-4e7b-bfcb-60f695ade146" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b34133e-df0b-4e7b-bfcb-60f695ade146">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DATA-RUMAH.csv to DATA-RUMAH.csv

# %%
df = pd.read_csv("DATA-RUMAH.csv")
df.head()
# Out:
#    NO                                         NAMA RUMAH       HARGA   LB  \
# 0   1  Rumah Murah Hook Tebet Timur, Tebet, Jakarta S...  3800000000  220
# 1   2  Rumah Modern di Tebet dekat Stasiun, Tebet, Ja...  4600000000  180
# 2   3  Rumah Mewah 2 Lantai Hanya 3 Menit Ke Tebet, T...  3000000000  267
# 3   4           Rumah Baru Tebet, Tebet, Jakarta Selatan   430000000   40
# 4   5  Rumah Bagus Tebet komp Gudang Peluru lt 350m, ...  9000000000  400
#
#     LT  KT  KM  GRS
# 0  220   3   3    0
# 1  137   4   3    2
# 2  250   4   4    4
# 3   25   2   2    0
# 4  355   6   5    3

# %%
plt.scatter(df.LT, df.HARGA, color = 'blue')
plt.xlabel("LUAS TANAH")
plt.ylabel("HARGA")
plt.show()

# %%
df.shape
# Out:
# (1010, 8)

# %%
df.describe()
# Out:
#                 NO         HARGA           LB           LT           KT  \
# count  1010.000000  1.010000e+03  1010.000000  1010.000000  1010.000000
# mean    505.500000  7.628987e+09   276.539604   237.432673     4.668317
# std     291.706188  7.340946e+09   177.864557   179.957604     1.572776
# min       1.000000  4.300000e+08    40.000000    25.000000     2.000000
# 25%     253.250000  3.262500e+09   150.000000   130.000000     4.000000
# 50%     505.500000  5.000000e+09   216.500000   165.000000     4.000000
# 75%     757.750000  9.000000e+09   350.000000   290.000000     5.000000
# max    1010.000000  6.500000e+10  1126.000000  1400.000000    10.000000
#
#                 KM          GRS
# count  1010.000000  1010.000000
# mean      3.607921     1.920792
# std       1.420066     1.510998
# min       1.000000     0.000000
# 25%       3.000000     1.000000
# 50%       3.000000     2.000000
# 75%       4.000000     2.000000
# max      10.000000    10.000000

# %%
df1 = df[['HARGA','LB','LT','KT','KM','GRS']]

df1.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 2  3000000000  267  250   4   4    4
# 3   430000000   40   25   2   2    0
# 4  9000000000  400  355   6   5    3

# %%
df1.describe()
# Out:
#               HARGA           LB           LT           KT           KM  \
# count  1.010000e+03  1010.000000  1010.000000  1010.000000  1010.000000
# mean   7.628987e+09   276.539604   237.432673     4.668317     3.607921
# std    7.340946e+09   177.864557   179.957604     1.572776     1.420066
# min    4.300000e+08    40.000000    25.000000     2.000000     1.000000
# 25%    3.262500e+09   150.000000   130.000000     4.000000     3.000000
# 50%    5.000000e+09   216.500000   165.000000     4.000000     3.000000
# 75%    9.000000e+09   350.000000   290.000000     5.000000     4.000000
# max    6.500000e+10  1126.000000  1400.000000    10.000000    10.000000
#
#                GRS
# count  1010.000000
# mean      1.920792
# std       1.510998
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max      10.000000

# %%
quantile1, quantile3 = np.percentile(df1.HARGA,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# -5343750000.0 17606250000.0

# %%
df2 = df1.loc[(df1['HARGA'] <= 17606250000)&(df1['LB'] <= 650)&(df1['LT']<=530)&(df1['KT'] >= 2.5)&(df1['KT']<=6.5)&(df1['KM'] >= 1.5)&(df1['KM'] <= 5.5)&(df1['GRS'] <= 3.5)]

df2.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 4  9000000000  400  355   6   5    3
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1

# %%
df2.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  6.950000e+02  695.000000  695.000000  695.000000  695.000000
# mean   5.195224e+09  217.789928  173.920863    4.192806    3.264748
# std    2.998139e+09   98.676759   83.006168    0.923722    0.899316
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    3.100000e+09  150.000000  114.000000    3.000000    3.000000
# 50%    4.000000e+09  200.000000  145.000000    4.000000    3.000000
# 75%    6.500000e+09  250.000000  220.000000    5.000000    4.000000
# max    1.600000e+10  646.000000  501.000000    6.000000    5.000000
#
#               GRS
# count  695.000000
# mean     1.526619
# std      0.831007
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df2.GRS,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# -0.5 3.5

# %%
df3 = df2.loc[(df1['HARGA'] <= 11600000000)&(df1['LB'] <= 400)&(df1['LT']<=379)]
df3.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 4  9000000000  400  355   6   5    3
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1

# %%
df3.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  6.300000e+02  630.000000  630.000000  630.000000  630.000000
# mean   4.551017e+09  199.214286  157.522222    4.147619    3.215873
# std    2.109764e+09   74.201377   64.780529    0.908598    0.890366
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    3.000000e+09  150.000000  110.000000    3.000000    3.000000
# 50%    3.900000e+09  180.000000  140.000000    4.000000    3.000000
# 75%    5.837500e+09  250.000000  189.750000    5.000000    4.000000
# max    1.100000e+10  400.000000  370.000000    6.000000    5.000000
#
#               GRS
# count  630.000000
# mean     1.525397
# std      0.825944
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df3.LT,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# -9.625 309.375

# %%
df4 = df3.loc[(df3['HARGA'] <= 10093750000)&(df3['LB'] <= 400)&(df3['LT']<=309)]
df4.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1
# 8  3250000000  125   90   3   3    0

# %%
df4.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  6.020000e+02  602.000000  602.000000  602.000000  602.000000
# mean   4.366679e+09  195.749169  150.260797    4.126246    3.204319
# std    1.911056e+09   72.469824   55.083480    0.906994    0.889829
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    3.000000e+09  150.000000  110.000000    3.000000    3.000000
# 50%    3.850000e+09  180.000000  137.000000    4.000000    3.000000
# 75%    5.500000e+09  249.250000  180.000000    5.000000    4.000000
# max    1.000000e+10  400.000000  306.000000    6.000000    5.000000
#
#               GRS
# count  602.000000
# mean     1.519934
# std      0.814041
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df4.LB,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# 1.125 398.125

# %%
df5 = df4.loc[(df4['HARGA'] <= 9250000000)&(df4['LB'] <= 398)&(df4['LT']<=285)]
df5.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1
# 8  3250000000  125   90   3   3    0

# %%
df5.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  5.700000e+02  570.000000  570.000000  570.000000  570.000000
# mean   4.147605e+09  188.505263  144.008772    4.098246    3.177193
# std    1.675849e+09   65.409035   48.447405    0.909333    0.882463
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    3.000000e+09  148.500000  107.000000    3.000000    3.000000
# 50%    3.750000e+09  175.000000  135.000000    4.000000    3.000000
# 75%    5.000000e+09  220.000000  165.000000    5.000000    4.000000
# max    9.000000e+09  390.000000  283.000000    6.000000    5.000000
#
#               GRS
# count  570.000000
# mean     1.508772
# std      0.800325
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df5.HARGA,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# 0.0 8000000000.0

# %%
df6 = df5.loc[(df5['HARGA'] <= 7876500000)&(df5['LB'] <= 329)&(df5['LT']<=245)]
df6.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1
# 8  3250000000  125   90   3   3    0

# %%
df6.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  5.000000e+02  500.000000  500.000000  500.000000  500.000000
# mean   3.768010e+09  177.312000  133.200000    4.040000    3.110000
# std    1.319179e+09   54.204676   37.868827    0.898897    0.859871
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    2.850000e+09  140.000000  100.000000    3.000000    2.000000
# 50%    3.500000e+09  170.000000  135.000000    4.000000    3.000000
# 75%    4.500000e+09  210.000000  150.000000    5.000000    4.000000
# max    7.500000e+09  325.000000  241.000000    6.000000    5.000000
#
#               GRS
# count  500.000000
# mean     1.458000
# std      0.778105
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df6.LT,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# 25.0 225.0

# %%
df7 = df6.loc[(df6['HARGA'] <= 6975000000)&(df6['LB'] <= 315)&(df6['LT']<=225)]
df7.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 5  4970000000  300  154   5   3    3
# 6  2600000000  120  150   3   2    1
# 8  3250000000  125   90   3   3    0

# %%
df7.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  4.750000e+02  475.000000  475.000000  475.000000  475.000000
# mean   3.662800e+09  172.648421  130.351579    4.008421    3.067368
# std    1.234162e+09   49.494582   35.650444    0.883470    0.841743
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    2.800000e+09  140.000000  100.000000    3.000000    2.000000
# 50%    3.500000e+09  162.000000  134.000000    4.000000    3.000000
# 75%    4.345000e+09  200.000000  150.000000    5.000000    4.000000
# max    6.950000e+09  300.000000  225.000000    6.000000    5.000000
#
#               GRS
# count  475.000000
# mean     1.444211
# std      0.767581
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df7.LT,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# 25.0 225.0

# %%
df8 = df7.loc[(df7['HARGA'] <= 6662500000)&(df7['LB'] <= 290)]
df8.head()
# Out:
#         HARGA   LB   LT  KT  KM  GRS
# 0  3800000000  220  220   3   3    0
# 1  4600000000  180  137   4   3    2
# 6  2600000000  120  150   3   2    1
# 8  3250000000  125   90   3   3    0
# 9  4500000000  250   96   5   4    1

# %%
df8.describe()
# Out:
#               HARGA          LB          LT          KT          KM  \
# count  4.620000e+02  462.000000  462.000000  462.000000  462.000000
# mean   3.606840e+09  169.714286  129.560606    4.006494    3.054113
# std    1.186206e+09   46.405697   35.555029    0.884894    0.840472
# min    7.500000e+08   56.000000   54.000000    3.000000    2.000000
# 25%    2.800000e+09  140.000000  100.000000    3.000000    2.000000
# 50%    3.500000e+09  160.000000  133.000000    4.000000    3.000000
# 75%    4.300000e+09  200.000000  148.750000    5.000000    4.000000
# max    6.500000e+09  280.000000  225.000000    6.000000    5.000000
#
#               GRS
# count  462.000000
# mean     1.430736
# std      0.767116
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
quantile1, quantile3 = np.percentile(df8.LB,[25,75])
iqr_value = quantile3 - quantile1
lower = quantile1 - (1.5*iqr_value)
upper = quantile3 + (1.5*iqr_value)

print(lower, upper)
# Out:
# 50.0 290.0

# %% [markdown]
# Gunakan data df8

# %%
print(df8.corr())
# Out:
#           HARGA        LB        LT        KT        KM       GRS
# HARGA  1.000000  0.563945  0.524849  0.296401  0.385373  0.380414
# LB     0.563945  1.000000  0.336377  0.319000  0.416354  0.352683
# LT     0.524849  0.336377  1.000000  0.242642 -0.000509  0.118536
# KT     0.296401  0.319000  0.242642  1.000000  0.428274  0.165235
# KM     0.385373  0.416354 -0.000509  0.428274  1.000000  0.306945
# GRS    0.380414  0.352683  0.118536  0.165235  0.306945  1.000000

# %%
df8.columns
# Out:
# Index(['HARGA', 'LB', 'LT', 'KT', 'KM', 'GRS'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df8, test_size=0.2, random_state=42)

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.73214286, 0.97076023, 0.        , 0.33333333, 0.        ],
#        [0.55357143, 0.48538012, 0.33333333, 0.33333333, 0.66666667],
#        [0.28571429, 0.56140351, 0.        , 0.        , 0.33333333],
#        ...,
#        [0.32142857, 0.21052632, 0.        , 0.33333333, 0.33333333],
#        [0.19642857, 0.50292398, 0.        , 0.        , 0.33333333],
#        [0.46428571, 0.50292398, 0.33333333, 0.33333333, 0.66666667]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (323, 5) (69, 5) (70, 5) (323,) (69,) (70,)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, batch_size=10, epochs=100, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-f0c8be6b60ff> in <module>()
# ----> 1 hist = model.fit(X_train, Y_train, batch_size=10, epochs=100, validation_data=(X_val, Y_val))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# ...

# %%
from sklearn import linear_model

msk = np.random.rand(len(df8)) < 0.8
train = df8[msk]
test = df8[~msk]

# %%
regr = linear_model.LinearRegression()

x = np.asanyarray(train[['LB', 'LT', 'KT', 'KM', 'GRS']])
y = np.asanyarray(train[['HARGA']])
regr.fit(x, y)
print('Coefficients: ', regr.coef_)
print('Intercept: ', regr.intercept_)

# %%
x = np.asanyarray(test[['LB', 'LT', 'KT', 'KM', 'GRS']])
y = np.asanyarray(test[['HARGA']])
y_hat = regr.predict(test[['LB', 'LT', 'KT', 'KM', 'GRS']])
print("Residual sum of squares: %.2f" % np.mean((y_hat - y) ** 2))
print("Variance score: %.2f" % regr.score(x, y))

# %%
regr = linear_model.LinearRegression()

x = np.asanyarray(train[['LB', 'LT', 'KM', 'GRS']])
y = np.asanyarray(train[['HARGA']])
regr.fit(x, y)
print('Coefficients: ', regr.coef_)
print('Intercept: ', regr.intercept_)

# %%
x = np.asanyarray(test[['LB', 'LT', 'KM', 'GRS']])
y = np.asanyarray(test[['HARGA']])
y_hat = regr.predict(test[['LB', 'LT', 'KM', 'GRS']])
print("Residual sum of squares: %.2f" % np.mean((y_hat - y) ** 2))
print("Variance score: %.2f" % regr.score(x, y))

# %%
regr = linear_model.LinearRegression()

x = np.asanyarray(train[['LB', 'LT', 'KM']])
y = np.asanyarray(train[['HARGA']])
regr.fit(x, y)
print('Coefficients: ', regr.coef_)
print('Intercept: ', regr.intercept_)

# %%
x = np.asanyarray(test[['LB', 'LT', 'KM']])
y = np.asanyarray(test[['HARGA']])
y_hat = regr.predict(test[['LB', 'LT', 'KM']])
print("Residual sum of squares: %.2f" % np.mean((y_hat - y) ** 2))
print("Variance score: %.2f" % regr.score(x, y))

# %% [markdown]
# $Harga = 6979178.20*LB + 12989898.4*LT - 14173126.1*KT + 310533423*KM + 264234677*GRS - 531734636$

# %%
x = eval(input('Masukkan Luas Bangunan yang diinginkan (m^2) :' ))
y = eval(input('Masukkan Luas Tanah yang diinginkan (m^2):' ))
z = eval(input('Masukkan Jumlah Kamar Tidur yang diinginkan: '))
w = eval(input('Masukkan Jumlah Kamar Mandi yang diinginkan: '))
v = eval(input('Masukkan Jumlah Mobil yang dapat disimpan dalam garasi: '))

def f(x,y,z,w,v):
  return (6979178.20*x + 12989898.4*y - 14173126.1*z + 310533423*w + 264234677*v - 531734636)

print('Harga rumah yang kamu inginkan adalah : Rp', f(x,y,z,w,v))

# %%
x = eval(input('Masukkan Luas Bangunan yang diinginkan (m^2) :' ))
y = eval(input('Masukkan Luas Tanah yang diinginkan (m^2):' ))
z = eval(input('Masukkan Jumlah Kamar mandi yang diinginkan: '))

def f(x,y,z):
  return (8477921.09*x + 13215881.9*y + 349124171*z - 609651413)

print('Harga rumah yang kamu inginkan adalah : Rp', f(x,y,z))
